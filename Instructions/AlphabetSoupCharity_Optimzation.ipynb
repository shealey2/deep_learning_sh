# %% [markdown]
# ## Preprocessing

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4829 sha256=35c93d904e79d34595e5e428792aac86e0d435c1ec379210ded2e8a3db6674d3
#   Stored in directory: c:\users\sean & lauren\appdata\local\pip\cache\wheels\a0\16\9c\5473df82468f958445479c59e784896fa24f4a5fc024b0f501
# Successfully built termcolor
# ...

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("../Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'

application_df = application_df.drop(['EIN','NAME'], axis=1)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
application_df.nunique()
# Out:
# APPLICATION_TYPE             9
# AFFILIATION                  6
# CLASSIFICATION               6
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
#cuttoff is 300
application_types_to_replace = ['T17','T29','T15','T25','T14','T2','T12','T13','T9']


# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C1580        1
# C2380        1
# C2600        1
# C4200        1
# C1728        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df['CLASSIFICATION'].value_counts().loc[lambda x : x>1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1237        9
# C1235        9
# C7210        7
# C1720        6
# C4100        6
# C2400        6
# C1257        5
# C1600        5
# C2710        3
# C1260        3
# C0           3
# C1256        2
# C1234        2
# C1246        2
# C3200        2
# C1267        2
# Name: CLASSIFICATION, dtype: int64

# %%
application_df['CLASSIFICATION'].unique()
# Out:
# array(['C1000', 'C2000', 'C3000', 'C1200', 'C2700', 'C7000', 'C7200',
#        'C1700', 'C4000', 'C7100', 'C2800', 'C6000', 'C2100', 'C1238',
#        'C5000', 'C7120', 'C1800', 'C4100', 'C1400', 'C1270', 'C2300',
#        'C8200', 'C1500', 'C7210', 'C1300', 'C1230', 'C1280', 'C1240',
#        'C2710', 'C2561', 'C1250', 'C8000', 'C1245', 'C1260', 'C1235',
#        'C1720', 'C1257', 'C4500', 'C2400', 'C8210', 'C1600', 'C1278',
#        'C1237', 'C4120', 'C2170', 'C1728', 'C1732', 'C2380', 'C1283',
#        'C1570', 'C2500', 'C1267', 'C3700', 'C1580', 'C2570', 'C1256',
#        'C1236', 'C1234', 'C1246', 'C2190', 'C4200', 'C0', 'C3200',
#        'C5200', 'C1370', 'C2600', 'C1248', 'C6100', 'C1820', 'C1900',
#        'C2150'], dtype=object)

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
#cutoff is 1000
classifications_to_replace= ['C2700', 'C7000', 'C7200',
       'C1700', 'C4000', 'C7100', 'C2800', 'C6000', 'C1238',
       'C5000', 'C7120', 'C1800', 'C4100', 'C1400', 'C1270', 'C2300',
       'C8200', 'C1500', 'C7210', 'C1300', 'C1230', 'C1280', 'C1240',
       'C2710', 'C2561', 'C1250', 'C8000', 'C1245', 'C1260', 'C1235',
       'C1720', 'C1257', 'C4500', 'C2400', 'C8210', 'C1600', 'C1278',
       'C1237', 'C4120', 'C2170', 'C1728', 'C1732', 'C2380', 'C1283',
       'C1570', 'C2500', 'C1267', 'C3700', 'C1580', 'C2570', 'C1256',
       'C1236', 'C1234', 'C1246', 'C2190', 'C4200', 'C0', 'C3200',
       'C5200', 'C1370', 'C2600', 'C1248', 'C6100', 'C1820', 'C1900',
       'C2150']

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies = pd.get_dummies(application_df)
print(dummies.columns)
dummies
# Out:
# Index(['STATUS', 'ASK_AMT', 'IS_SUCCESSFUL', 'APPLICATION_TYPE_Other',
#        'APPLICATION_TYPE_T10', 'APPLICATION_TYPE_T19', 'APPLICATION_TYPE_T3',
#        'APPLICATION_TYPE_T4', 'APPLICATION_TYPE_T5', 'APPLICATION_TYPE_T6',
#        'APPLICATION_TYPE_T7', 'APPLICATION_TYPE_T8',
#        'AFFILIATION_CompanySponsored', 'AFFILIATION_Family/Parent',
#        'AFFILIATION_Independent', 'AFFILIATION_National', 'AFFILIATION_Other',
#        'AFFILIATION_Regional', 'CLASSIFICATION_C1000', 'CLASSIFICATION_C1200',
#        'CLASSIFICATION_C2000', 'CLASSIFICATION_C2100', 'CLASSIFICATION_C3000',
#        'CLASSIFICATION_Other', 'USE_CASE_CommunityServ', 'USE_CASE_Heathcare',
#        'USE_CASE_Other', 'USE_CASE_Preservation', 'USE_CASE_ProductDev',
#        'ORGANIZATION_Association', 'ORGANIZATION_Co-operative',
#        'ORGANIZATION_Corporation', 'ORGANIZATION_Trust', 'INCOME_AMT_0',
#        'INCOME_AMT_1-9999', 'INCOME_AMT_10000-24999',
# ...

# %%
# Split our preprocessed data into our features and target arrays
X_dummies = dummies.drop('IS_SUCCESSFUL', axis=1)
y=dummies['IS_SUCCESSFUL']


# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %% [markdown]
# #### Test 1

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=8, activation="relu", input_dim=43))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=6, activation="relu", input_dim=43))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=3, activation='tanh', input_dim=43))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units=8, activation='tanh', input_dim=43))

# Fifth hidden layer
nn.add(tf.keras.layers.Dense(units=5, activation="sigmoid", input_dim=43))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()

# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_34 (Dense)            (None, 8)                 352
#
#  dense_35 (Dense)            (None, 6)                 54
#
#  dense_36 (Dense)            (None, 3)                 21
#
#  dense_37 (Dense)            (None, 8)                 32
#
#  dense_38 (Dense)            (None, 5)                 45
#
#  dense_39 (Dense)            (None, 1)                 6
#
# ...
# Total params: 510
# Trainable params: 510
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 804/804 [==============================] - 1s 956us/step - loss: 0.6131 - accuracy: 0.6788
# Epoch 2/50
# 804/804 [==============================] - 1s 708us/step - loss: 0.5650 - accuracy: 0.7282
# Epoch 3/50
# 804/804 [==============================] - 1s 772us/step - loss: 0.5610 - accuracy: 0.7298
# Epoch 4/50
# ...

# %% [markdown]
# #### Test 2

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=8, activation="relu", input_dim=43))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=1, activation="relu", input_dim=43))



# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()

# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_40 (Dense)            (None, 8)                 352
#
#  dense_41 (Dense)            (None, 1)                 9
#
#  dense_42 (Dense)            (None, 1)                 2
#
# ...
# Total params: 363
# Trainable params: 363
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 804/804 [==============================] - 1s 498us/step - loss: 0.6813 - accuracy: 0.6530
# Epoch 2/50
# 804/804 [==============================] - 0s 510us/step - loss: 0.5896 - accuracy: 0.7184
# Epoch 3/50
# 804/804 [==============================] - 0s 512us/step - loss: 0.5776 - accuracy: 0.7211
# Epoch 4/50
# 804/804 [==============================] - 0s 508us/step - loss: 0.5740 - accuracy: 0.7220
# Epoch 5/50
# ...

# %% [markdown]
# #### Test 3

# %%
nn = tf.keras.models.Sequential()

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=3, activation='tanh', input_dim=43))

# Fourth hidden layer
nn.add(tf.keras.layers.Dense(units=8, activation='tanh', input_dim=43))

# Fifth hidden layer
nn.add(tf.keras.layers.Dense(units=5, activation="sigmoid", input_dim=43))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()

# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=50)

# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_43 (Dense)            (None, 3)                 132
#
#  dense_44 (Dense)            (None, 8)                 32
#
#  dense_45 (Dense)            (None, 5)                 45
#
#  dense_46 (Dense)            (None, 1)                 6
#
# ...
# Total params: 215
# Trainable params: 215
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 804/804 [==============================] - 1s 656us/step - loss: 0.6128 - accuracy: 0.6882
# Epoch 2/50
# 804/804 [==============================] - 1s 704us/step - loss: 0.5711 - accuracy: 0.7278
# Epoch 3/50
# 804/804 [==============================] - 0s 574us/step - loss: 0.5662 - accuracy: 0.7283
# Epoch 4/50
# 804/804 [==============================] - 0s 594us/step - loss: 0.5632 - accuracy: 0.7279
# Epoch 5/50
# ...

# %%
# Export our model to HDF5 file
import h5py
f1 = h5py.File("data.hdf5", "w")
